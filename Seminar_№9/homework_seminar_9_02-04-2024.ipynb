# %% [markdown]
# ## Домашнее задание к уроку № 9.<br>
# ## Инструменты разметки наборов данных
#
# ### Задание 1.<br>
# Выберите датасет, который имеет отношение к вашей области интересов или исследований. Датасет должен содержать неструктурированные данные, требующие разметки для решения конкретной задачи, например, анализа настроений или распознавания именованных сущностей.
#
# ### Задание 2.<br>
# Выполните разметку на основе правил (rule-based labeling) на подмножестве выбранного датасета. Разработайте и реализуйте набор правил или условий, которые позволят автоматически присваивать метки данным на основе определенных шаблонов или критериев.
#
# ### Задача 3.<br>
# Выполните разметку вручную отдельного подмножества выбранного датасета с помощью выбранного вами инструмента разметки.
#
# ### Задача 4.<br>
# Объедините данные, размеченные вручную, с данными, размеченными на основе правил. Объедините два подмножества размеченных данных в один набор данных, сохранив при этом соответствующую структуру и целостность.
#
# ### Задача 5.<br>
# Обучите модель машинного обучения, используя объединенный набор размеченных данных. Разделите датасет на обучающий и тестовый наборы и используйте обучающий набор для обучения модели.
#
# ### Задача 6.<br>
# Оценить эффективность обученной модели на тестовом датасете. Используйте подходящие метрики оценки. Интерпретируйте результаты и проанализируйте эффективность модели в решении задачи разметки.

# %%
import pandas as pd
import numpy as np
import pathlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### Задание 1.<br>
# Выберите датасет, который имеет отношение к вашей области интересов или исследований. Датасет должен содержать неструктурированные данные, требующие разметки для решения конкретной задачи, например, анализа настроений или распознавания именованных сущностей.

# %% [markdown]
# Т.к. я - биоинформатик, то я выбрал набор данных из своей работы - это данные измерений морфо-анатомических, физиологических и биохимических показателей 12000 пациентов-мужчин из российской популяции в возрасте от 37 до 74 лет с бессимптомным течением атеросклероза.<br>
# Для каждого пациента были измерены эти показатели на следующих этапах исследования: в начале исследования, через 3 месяца исследования, через 6 месяцев исследования, через 9 месяцев исследования и через 12 месяцев исследования.

# %%
#### Получение полного пути до файла с данными

FileNameFull = "atherosclerosis_dataset.xlsx"
print(FileNameFull)

#### Чтение файла Excel с данными
input_df = pd.read_excel(FileNameFull, engine='openpyxl')
input_df
# Out:
# atherosclerosis_dataset.xlsx
#           valid  age  sys  dia  sm  inf  an         cho          tg  \
# 0      1.000000   56  130   80   0    0   1  238.000000  181.000000
# 1      1.000000   63  140   90   0    1   0  189.000000  203.000000
# 2      1.000000   49  120   80   1    1   1  284.000000  226.000000
# 3      1.000000   62  130   80   1    0   0  218.000000  265.000000
# 4      1.000000   57  120   80   0    0   0  154.000000   89.000000
# ...         ...  ...  ...  ...  ..  ...  ..         ...         ...
# 11995  1.019382   37  110   70   1    1   0  214.000060  295.254327
# 11996  1.029241   37  110   70   1    1   0  225.359522  289.244412
# 11997  0.929817   37  110   70   1    1   0  259.026246  268.780057
# 11998  0.845250   37  110   70   1    1   0  219.149244  323.959319
# 11999  1.124269   37  110   70   1    1   0  230.965568  245.414542
#
#              hdl  ...    d_atg_r   AMI_risk   CHD_risk  VAR00002  \
# 0      35.500000  ...        NaN   7.800000  17.000000         1
# 1      29.400000  ... -36.111111   8.000000  22.700000         1
# 2      31.400000  ... -20.622568  12.900000  23.000000         1
# 3      53.800000  ... -11.061947   5.500000  18.700000         1
# 4      52.800000  ...  22.000000   1.000000   5.400000         1
# ...          ...  ...        ...        ...        ...       ...
# 11995  31.569550  ...  34.708181   1.681898   8.714630         0
# 11996  27.966268  ...  36.916634   1.621065   7.940207         0
# 11997  30.433315  ...  34.298281   1.815233   9.956535         0
# 11998  38.693567  ...  34.278444   1.879601  10.194996         0
# 11999  35.733525  ...  32.475101   1.769624   9.865889         0
#
#        atherosclerosis type month 0  atherosclerosis type month 3  \
# 0                            normal                        normal
# 1                            normal                        normal
# 2                           at risk               atherosclerosis
# 3                            normal                        normal
# 4                           at risk                       at risk
# ...                             ...                           ...
# 11995                        normal                       at risk
# 11996                        normal                       at risk
# 11997                        normal                       at risk
# 11998                        normal                       at risk
# 11999                        normal                       at risk
#
#        atherosclerosis type month 6  atherosclerosis type month 9  \
# 0                            normal                        normal
# 1                           at risk                        normal
# 2                   atherosclerosis               atherosclerosis
# 3                           at risk                        normal
# 4                           at risk                       at risk
# ...                             ...                           ...
# 11995                       at risk                       at risk
# 11996                       at risk                       at risk
# 11997                       at risk                       at risk
# 11998                       at risk                       at risk
# 11999                       at risk                       at risk
#
#        atherosclerosis type month 12  age_group
# 0                             normal     middle
# 1                             normal     middle
# 2                            at risk     middle
# 3                             normal     middle
# 4                            at risk     middle
# ...                              ...        ...
# 11995                         normal        low
# 11996                         normal        low
# 11997                         normal        low
# 11998                         normal        low
# 11999                         normal        low
#
# [12000 rows x 67 columns]

# %% [markdown]
# Цель данных исследований (и существования набора данных) - создать модель, прогнозирующую возникновение и развитие атеросклероза у пациента на основании биохимического анализа крови. Для этого на каждом из этих этапов для каждого пациента был определен статус здоровья относительно атеросклероза: «норма», «предрасположенность», «атеросклероз».

# %% [markdown]
# ### Задание 2.<br>
# Выполните разметку на основе правил (rule-based labeling) на подмножестве выбранного датасета. Разработайте и реализуйте набор правил или условий, которые позволят автоматически присваивать метки данным на основе определенных шаблонов или критериев.

# %% [markdown]
# Разметкой данного набора данных считается указание для каждого пациента (пациенту соответствует строка датасета) статуса здоровья относительно атеросклероза: норма (normal), предрасположенность (at risk), атеросклероз (atherosclerosis).<br>
# В медицинской практике атеросклероз определяется на основании ультразвукового исследования (УЗИ) некоторых магистральных кровеносных сосудов. Значением «норма» относительно статута здоровья считались следующие значения толщинs интимо-медиального (срединного) слоя сонной артерии соответственно: у мужчин до 40 лет - 0,7 мм ±0,1 мм, для мужчин от 40 до 50 лет - 0,8 мм ±0,1 мм, старше 50 лет - 0,9 мм ±0,1 мм. 5. Для значения «атеросклероз» маркерными считались следующие значения толщины интимо-медиального слоя вне зависимости от возраста: 1,3 мм ±0,1 мм. Для значения «предрасположенность» маркерными считались значения толщины интимо-медиального слоя, промежуточные между «нормой» и «атеросклерозом».<br>

# %% [markdown]
# ### В принципе, данный набор данных служит для моделирования сложных процессов поражения сосудистой стенки в зависимомти от биохимических реакций в организме человека, но мы для учебных целей будем автоматизировать простую механическую работу, которую делает любой врач УЗД - диагностирует атеросклероз на основании данных УЗИ артерий пациента.

# %%
### Функция для разметки основанной на правилах
### age_column - возраст пациентов
### vs_column - толщина сонной артерии пациентов 

def assign_category(row, age_column, vs_column):
    if row[age_column] < 40.0 and (row[vs_column] >= 0.6 and row[vs_column] <= 0.8):
        return 'normal'
    elif (row[age_column] >= 40.0 and row[age_column] <= 50) and row[vs_column] <= 0.9:
        return 'normal'
    elif row[age_column] > 50.0 and row[vs_column] <= 1.0:
        return 'normal'
    elif row[vs_column] >= 1.2:
        return 'atherosclerosis'
    elif row[vs_column] > 0.8 and row[vs_column] < 1.2:
        return 'at risk'
    else:
        return 'неизвестно'

# %% [markdown]
# ### Дальнейшаяя работа проводится только на примере показателей, измеренных к пациентов в ПЕРВЫЙ месяц обследований

# %%
### Для решения задачи разметки нужно убедиться что для всех пациентов заполнены поля 
# с возрастом и с измерением толщины сонной артерии в первый месяц исследования, т.е. обработать пропущенные значения,
# заполнив их среднеарифмитическими оценками

input_df[['age', 'vs0']].info()

### Вывод: все необходимые поля набора данных полностью заполнены
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     12000 non-null  int64
#  1   vs0     12000 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 187.6 KB

# %%
### Разметка набора данных для первого месяца обследования пациентов, основанная на правилах
### 'atherosclerosis type month 0' - поле статуса здоровья пациента по отношению к
### атеросклерозу при обследовании пациента в первый месяц

input_df['atherosclerosis type month 0'] = input_df.apply(assign_category, args=('age', 'vs0'), axis=1)

# %%
### Проверим - все ли пациенты были размечены по статусу атеросклероза
input_df['atherosclerosis type month 0'].value_counts()

### Вывод: переменная-отклик заполнена полностью
# Out:
# atherosclerosis type month 0
# normal             5439
# at risk            4793
# atherosclerosis    1768
# Name: count, dtype: int64

# %% [markdown]
# ### Задача 3.<br>
# Выполните разметку вручную отдельного подмножества выбранного датасета с помощью выбранного вами инструмента разметки.

# %%
### Выделим из общего набора данных необходимые данные для ручной разметки в отдельный файл

df = input_df[['age', 'vs0', 'atherosclerosis type month 0']]

FileNameFull = "atherosclerosis_dataset_manual.csv"

df.to_csv(FileNameFull, index = False)

### Разметку  для первых 50 пациентов (для учебных целей) я проводит в Label Studio.
#   Скриншот этой работы приложен в папку вместе с этим .ipynb файлом

# %% [markdown]
# ### Задача 4.<br>
# Объедините данные, размеченные вручную, с данными, размеченными на основе правил. Объедините два подмножества размеченных данных в один набор данных, сохранив при этом соответствующую структуру и целостность.

# %%
# Загрузка датасета с ручной разметкой
manual_df = pd.read_csv('atherosclerosis_dataset_manual.csv', engine='python')

### Объдиняем существующий датасет с датасетом с размещенными вручную значениями

df = pd.merge(input_df, manual_df, on = ['age', 'vs0'], how = 'inner')
df
# Out:
#           valid  age  sys  dia  sm  inf  an         cho          tg  \
# 0      1.000000   63  140   90   0    1   0  189.000000  203.000000
# 1      1.000000   49  120   80   1    1   1  284.000000  226.000000
# 2      1.000000   62  130   80   1    0   0  218.000000  265.000000
# 3      1.000000   57  120   80   0    0   0  154.000000   89.000000
# 4      1.000000   54  125   70   0    0   1  250.000000  233.000000
# ...         ...  ...  ...  ...  ..  ...  ..         ...         ...
# 10387  1.019382   37  110   70   1    1   0  214.000060  295.254327
# 10388  1.029241   37  110   70   1    1   0  225.359522  289.244412
# 10389  0.929817   37  110   70   1    1   0  259.026246  268.780057
# 10390  0.845250   37  110   70   1    1   0  219.149244  323.959319
# 10391  1.124269   37  110   70   1    1   0  230.965568  245.414542
#
#              hdl  ...   AMI_risk   CHD_risk  VAR00002  \
# 0      29.400000  ...   8.000000  22.700000         1
# 1      31.400000  ...  12.900000  23.000000         1
# 2      53.800000  ...   5.500000  18.700000         1
# 3      52.800000  ...   1.000000   5.400000         1
# 4      46.300000  ...   4.000000  11.500000         1
# ...          ...  ...        ...        ...       ...
# 10387  31.569550  ...   1.681898   8.714630         0
# 10388  27.966268  ...   1.621065   7.940207         0
# 10389  30.433315  ...   1.815233   9.956535         0
# 10390  38.693567  ...   1.879601  10.194996         0
# 10391  35.733525  ...   1.769624   9.865889         0
#
#        atherosclerosis type month 0_x  atherosclerosis type month 3  \
# 0                              normal                        normal
# 1                     atherosclerosis               atherosclerosis
# 2                              normal                        normal
# 3                              normal                       at risk
# 4                              normal                       at risk
# ...                               ...                           ...
# 10387                         at risk                       at risk
# 10388                         at risk                       at risk
# 10389                         at risk                       at risk
# 10390                         at risk                       at risk
# 10391                         at risk                       at risk
#
#        atherosclerosis type month 6  atherosclerosis type month 9  \
# 0                           at risk                        normal
# 1                   atherosclerosis               atherosclerosis
# 2                           at risk                        normal
# 3                           at risk                       at risk
# 4                           at risk                       at risk
# ...                             ...                           ...
# 10387                       at risk                       at risk
# 10388                       at risk                       at risk
# 10389                       at risk                       at risk
# 10390                       at risk                       at risk
# 10391                       at risk                       at risk
#
#        atherosclerosis type month 12  age_group  \
# 0                             normal     middle
# 1                            at risk     middle
# 2                             normal     middle
# 3                            at risk     middle
# 4                             normal     middle
# ...                              ...        ...
# 10387                         normal        low
# 10388                         normal        low
# 10389                         normal        low
# 10390                         normal        low
# 10391                         normal        low
#
#        atherosclerosis type month 0_y
# 0                              normal
# 1                     atherosclerosis
# 2                              normal
# 3                              normal
# 4                              normal
# ...                               ...
# 10387                         at risk
# 10388                         at risk
# 10389                         at risk
# 10390                         at risk
# 10391                         at risk
#
# [10392 rows x 68 columns]

# %%
### переименовываем столбец atherosclerosis type month 0_y в atherosclerosis type month 0

old_column_name = 'atherosclerosis type month 0_y'
new_column_name = 'atherosclerosis type month 0'
df.rename(columns={old_column_name: new_column_name}, inplace=True)

# %% [markdown]
# ### Задача 5.<br>
# Обучите модель машинного обучения, используя объединенный набор размеченных данных. Разделите датасет на обучающий и тестовый наборы и используйте обучающий набор для обучения модели.

# %%
# Перекодирование категориальной переменной
label_encoder = LabelEncoder()
df['atherosclerosis type month 0'] = label_encoder.fit_transform(df['atherosclerosis type month 0'])

# %%
# Разделение выборок на обучающую и тестовую
X = df[['age', 'vs0']].values
y = df['atherosclerosis type month 0'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
# Определяем простую модель ИНС прямого распространения 
# с тремя слоями нейронов для двух входных переменных и 
# трех выходов.

model = Sequential([
    Dense(10, input_dim=2, activation='relu'),
    Dense(10, activation='relu'),
    Dense(3, activation='softmax')
])
# Out:
# c:\Program Files\Python311\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Компиляция модели
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Обучение модели
history = model.fit(X_train, y_train, epochs=75, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.3296 - loss: 1.0106 - val_accuracy: 0.4541 - val_loss: 0.9647
# Epoch 2/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4921 - loss: 0.9389 - val_accuracy: 0.5847 - val_loss: 0.8802
# Epoch 3/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5763 - loss: 0.8452 - val_accuracy: 0.6046 - val_loss: 0.7797
# Epoch 4/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6168 - loss: 0.7502 - val_accuracy: 0.5853 - val_loss: 0.7235
# Epoch 5/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6439 - loss: 0.6892 - val_accuracy: 0.7547 - val_loss: 0.6482
# Epoch 6/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7038 - loss: 0.6368 - val_accuracy: 0.7598 - val_loss: 0.6182
# Epoch 7/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7345 - loss: 0.6066 - val_accuracy: 0.8146 - val_loss: 0.6235
# Epoch 8/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.5982 - val_accuracy: 0.8198 - val_loss: 0.5817
# Epoch 9/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7658 - loss: 0.5721 - val_accuracy: 0.7386 - val_loss: 0.5640
# Epoch 10/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7711 - loss: 0.5482 - val_accuracy: 0.7046 - val_loss: 0.5923
# Epoch 11/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7814 - loss: 0.5552 - val_accuracy: 0.8589 - val_loss: 0.5474
# Epoch 12/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8081 - loss: 0.5201 - val_accuracy: 0.7723 - val_loss: 0.5260
# Epoch 13/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7984 - loss: 0.5121 - val_accuracy: 0.7761 - val_loss: 0.5182
# Epoch 14/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8206 - loss: 0.5011 - val_accuracy: 0.8262 - val_loss: 0.5018
# Epoch 15/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8139 - loss: 0.4768 - val_accuracy: 0.8579 - val_loss: 0.5036
# Epoch 16/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8267 - loss: 0.4816 - val_accuracy: 0.8663 - val_loss: 0.5106
# Epoch 17/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8222 - loss: 0.4681 - val_accuracy: 0.8101 - val_loss: 0.4719
# Epoch 18/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8297 - loss: 0.4580 - val_accuracy: 0.8111 - val_loss: 0.4672
# Epoch 19/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8255 - loss: 0.4534 - val_accuracy: 0.8044 - val_loss: 0.4619
# Epoch 20/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8360 - loss: 0.4410 - val_accuracy: 0.8618 - val_loss: 0.4524
# Epoch 21/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8380 - loss: 0.4406 - val_accuracy: 0.8525 - val_loss: 0.4541
# Epoch 22/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8510 - loss: 0.4263 - val_accuracy: 0.7842 - val_loss: 0.5216
# Epoch 23/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8487 - loss: 0.4350 - val_accuracy: 0.8602 - val_loss: 0.4262
# Epoch 24/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8387 - loss: 0.4146 - val_accuracy: 0.8249 - val_loss: 0.4393
# Epoch 25/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8613 - loss: 0.4031 - val_accuracy: 0.8364 - val_loss: 0.4200
# Epoch 26/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8625 - loss: 0.4009 - val_accuracy: 0.8833 - val_loss: 0.4273
# Epoch 27/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8581 - loss: 0.4082 - val_accuracy: 0.8464 - val_loss: 0.4103
# Epoch 28/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.3961 - val_accuracy: 0.8813 - val_loss: 0.3991
# Epoch 29/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8642 - loss: 0.3713 - val_accuracy: 0.8817 - val_loss: 0.4256
# Epoch 30/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8680 - loss: 0.3666 - val_accuracy: 0.8531 - val_loss: 0.4041
# Epoch 31/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8683 - loss: 0.3751 - val_accuracy: 0.8602 - val_loss: 0.3928
# Epoch 32/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8601 - loss: 0.3752 - val_accuracy: 0.8400 - val_loss: 0.4137
# Epoch 33/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8651 - loss: 0.3776 - val_accuracy: 0.8724 - val_loss: 0.3790
# Epoch 34/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8823 - loss: 0.3488 - val_accuracy: 0.8945 - val_loss: 0.3777
# Epoch 35/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8908 - loss: 0.3308 - val_accuracy: 0.8900 - val_loss: 0.3566
# Epoch 36/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8813 - loss: 0.3558 - val_accuracy: 0.8861 - val_loss: 0.3586
# Epoch 37/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8857 - loss: 0.3271 - val_accuracy: 0.9047 - val_loss: 0.3517
# Epoch 38/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8870 - loss: 0.3248 - val_accuracy: 0.8768 - val_loss: 0.3467
# Epoch 39/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8884 - loss: 0.3234 - val_accuracy: 0.9041 - val_loss: 0.3430
# Epoch 40/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8884 - loss: 0.3078 - val_accuracy: 0.8958 - val_loss: 0.3407
# Epoch 41/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8902 - loss: 0.3189 - val_accuracy: 0.8983 - val_loss: 0.3314
# Epoch 42/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8959 - loss: 0.3070 - val_accuracy: 0.9025 - val_loss: 0.3455
# Epoch 43/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8976 - loss: 0.2994 - val_accuracy: 0.9070 - val_loss: 0.3324
# Epoch 44/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8976 - loss: 0.3060 - val_accuracy: 0.8935 - val_loss: 0.3171
# Epoch 45/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8961 - loss: 0.2914 - val_accuracy: 0.9070 - val_loss: 0.3099
# Epoch 46/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8941 - loss: 0.2876 - val_accuracy: 0.9057 - val_loss: 0.3081
# Epoch 47/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8984 - loss: 0.2917 - val_accuracy: 0.8977 - val_loss: 0.3076
# Epoch 48/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9073 - loss: 0.2697 - val_accuracy: 0.9163 - val_loss: 0.3091
# Epoch 49/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8990 - loss: 0.2863 - val_accuracy: 0.8858 - val_loss: 0.3023
# Epoch 50/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9092 - loss: 0.2607 - val_accuracy: 0.9157 - val_loss: 0.2998
# Epoch 51/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9060 - loss: 0.2901 - val_accuracy: 0.8887 - val_loss: 0.3226
# Epoch 52/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9052 - loss: 0.2680 - val_accuracy: 0.9185 - val_loss: 0.2773
# Epoch 53/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9032 - loss: 0.2737 - val_accuracy: 0.9153 - val_loss: 0.2763
# Epoch 54/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9108 - loss: 0.2577 - val_accuracy: 0.8775 - val_loss: 0.3405
# Epoch 55/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9003 - loss: 0.2725 - val_accuracy: 0.9201 - val_loss: 0.2826
# Epoch 56/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9165 - loss: 0.2356 - val_accuracy: 0.9124 - val_loss: 0.2728
# Epoch 57/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9041 - loss: 0.2536 - val_accuracy: 0.9349 - val_loss: 0.2614
# Epoch 58/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9171 - loss: 0.2399 - val_accuracy: 0.9150 - val_loss: 0.2650
# Epoch 59/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9200 - loss: 0.2350 - val_accuracy: 0.9259 - val_loss: 0.2475
# Epoch 60/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9149 - loss: 0.2443 - val_accuracy: 0.9137 - val_loss: 0.2521
# Epoch 61/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9241 - loss: 0.2237 - val_accuracy: 0.9169 - val_loss: 0.2470
# Epoch 62/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9227 - loss: 0.2247 - val_accuracy: 0.9266 - val_loss: 0.2393
# Epoch 63/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9218 - loss: 0.2272 - val_accuracy: 0.9266 - val_loss: 0.2402
# Epoch 64/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9247 - loss: 0.2278 - val_accuracy: 0.9333 - val_loss: 0.2309
# Epoch 65/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9269 - loss: 0.2200 - val_accuracy: 0.8916 - val_loss: 0.2709
# Epoch 66/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9254 - loss: 0.2203 - val_accuracy: 0.9243 - val_loss: 0.2472
# Epoch 67/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9288 - loss: 0.2150 - val_accuracy: 0.9464 - val_loss: 0.2192
# Epoch 68/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9321 - loss: 0.2023 - val_accuracy: 0.9429 - val_loss: 0.2143
# Epoch 69/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9263 - loss: 0.2114 - val_accuracy: 0.9442 - val_loss: 0.2117
# Epoch 70/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9322 - loss: 0.2035 - val_accuracy: 0.9256 - val_loss: 0.2175
# Epoch 71/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9332 - loss: 0.1846 - val_accuracy: 0.9432 - val_loss: 0.2102
# Epoch 72/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9378 - loss: 0.1830 - val_accuracy: 0.9471 - val_loss: 0.2004
# Epoch 73/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9395 - loss: 0.1798 - val_accuracy: 0.9359 - val_loss: 0.2015
# Epoch 74/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9429 - loss: 0.1926 - val_accuracy: 0.9304 - val_loss: 0.2068
# Epoch 75/75
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9424 - loss: 0.1752 - val_accuracy: 0.9455 - val_loss: 0.1938

# %% [markdown]
# ### Задача 6.<br>
# Оценить эффективность обученной модели на тестовом датасете. Используйте подходящие метрики оценки. Интерпретируйте результаты и проанализируйте эффективность модели в решении задачи разметки.

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Точность модели')
plt.ylabel('точность')
plt.xlabel('количество эпох')
plt.legend(['Обучение', 'Тестирование'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Потери модели')
plt.ylabel('Потери')
plt.xlabel('количество эпох')
plt.legend(['Обучение', 'Тестирование'], loc='upper right')
plt.show()

# %%
# Расчет некоторых других метрик качества модели
loss, accuracy = model.evaluate(X_test, y_test)
y_test_predicted = np.argmax(model.predict(X_test), axis=1)
f1 = f1_score(y_test, y_test_predicted, average='weighted')
print(f'Test Loss (Потери): {loss},\nTest Accuracy (Точность): {accuracy}')
print(f'F-score = {f1}')
# Out:
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9453 - loss: 0.1947
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Test Loss (Потери): 0.19377198815345764,
# Test Accuracy (Точность): 0.9454778432846069
# F-score = 0.9455728079899093

# %% [markdown]
# ### Вывод: эффективность модели в решении задачи разметки при точности 94% можно считать хорошей.
