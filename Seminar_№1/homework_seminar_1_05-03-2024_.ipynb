# %% [markdown]
# ## Задачи 3 - 7:
# 3. Сценарий Foursquare
# 4. Напишите сценарий на языке Python, который предложит пользователю ввести интересующую его категорию (например, кофейни, музеи, парки и т.д.).
# 5. Используйте API Foursquare для поиска заведений в указанной категории.
# 6. Получите название заведения, его адрес и рейтинг для каждого из них.
# 7. Скрипт должен вывести название и адрес и рейтинг каждого заведения в консоль.

# %%
import os
import requests
from dotenv import load_dotenv
from fake_useragent import UserAgent
from pprint import pprint

# %%
ua = UserAgent() #### для указания "браузера"

# %%
category = input("Введите название интересующей Вас категории на английском языке (например: Park, Zoos, Museums и т.п.) : ")

# %%
url = "https://api.foursquare.com/v3/places/search"

# %%
params = {
    'limit': 50,
    'query': category,
    'fields': 'name,location,rating'
}

# %%
headers = {
    "User-Agent": ua.firefox,
    "Accept": "application/json",
    "Authorization": "fsq3P6zWw5hrHAp69JoTu+0TFeYEBCEXDIo7+Ivypcz/4Uo="
}

# %%
response = requests.request("GET", url, params=params, headers=headers)

# %%
if response.status_code == 200:
    print("Успешный запрос API по URL: ", response.url)
else:
    print("Запрос API отклонен с кодом состояния:", response.status_code)
# Out:
# Успешный запрос API по URL:  https://api.foursquare.com/v3/places/search?limit=50&query=Park&fields=name%2Clocation%2Crating

# %%
data = response.json()
### pprint(data) ### для отображения структуры ответа

# %%
establishments = []
for place in data['results']:
    place_name = place.get('name')
    place_address = place.get('location')['formatted_address']
    place_rating = place.get('rating') if 'rating' in place else "Рейтинг не определялся"
    establishments.append({'name': place_name, 'address': place_address, 'rating': place_rating})

# %%
for establishment in establishments:
        print(f"Название: {establishment['name']}")
        print(f"Адрес: {establishment['address']}")
        print(f"Рейтинг: {establishment['rating']}")
        print()
# Out:
# Название: Park
# Адрес: Усачева, 29, Москва
# Рейтинг: 7.0
#
# Название: PARK
# Адрес: Ленинградский Пр., 1, 125040, Москва
# Рейтинг: Рейтинг не определялся
#
# Название: Muzeon Park (Парк искусств «Музеон»)
# Адрес: ул. Крымский Вал, 119049, Москва
# Рейтинг: 9.4
#
# Название: Gorky Park (ЦПКиО им. Горького)
# Адрес: Крымский Вал Ул., д. 9, 119049, Москва
# Рейтинг: 9.3
#
# Название: Novodevichy Park (Парк «Новодевичьи пруды»)
# Адрес: Новодевичий Пр., 1, Москва
# Рейтинг: 9.2
#
# Название: Victory Park (Парк Победы (Поклонная гора))
# Адрес: 121108, Москва
# Рейтинг: 8.9
#
# Название: Zaryadye Park (Парк «Зарядье»)
# Адрес: ул. Варварка, 109012, Москва
# Рейтинг: 7.5
#
# Название: Ararat Park Hyatt
# Адрес: Неглинная Ул., д. 4, 109012, Москва
# Рейтинг: 9.0
#
# Название: Aleksandrovskiy Garden (Александровский сад)
# Адрес: 119019, Москва
# Рейтинг: 9.1
#
# Название: Patriarshiye Ponds (Патриаршие пруды)
# Адрес: Большой Патриарший пер., Москва
# Рейтинг: 9.0
#
# Название: Neskuchny Garden (Нескучный сад)
# Адрес: 119071, Москва
# Рейтинг: 9.3
#
# Название: Сквер Девичьего поля
# Адрес: ул. Еланского, 119121, Москва
# Рейтинг: 8.8
#
# Название: КРАСНАЯ ПРЕСНЯ ПКиО
# Адрес: Мантулинская Ул., д. 5 (1-й Красногвардейский пр.), 123100, Москва
# Рейтинг: 8.9
#
# Название: Екатерининский парк
# Адрес: Екатерининская Б. Ул., д. 27 (Олимпийский просп.), 129110, Москва
# Рейтинг: 8.9
#
# Название: Vorobyovy Gory (Природный заказник «Воробьёвы горы»)
# Адрес: ул. Косыгина, Москва
# Рейтинг: 9.2
#
# Название: Академический парк
# Адрес: Черёмушкинский пр., 117312, Москва
# Рейтинг: 9.1
#
# Название: Лужники
# Адрес: Лужнецкая наб., Москва
# Рейтинг: 8.8
#
# Название: Парк Дворца Пионеров
# Адрес: Москва
# Рейтинг: 8.9
#
# Название: Останкино
# Адрес: Ботаническая ул., Москва
# Рейтинг: 9.3
#
# Название: Дубки
# Адрес: Москва
# Рейтинг: 9.1
#
# Название: Фили (ПКиО «Фили»)
# Адрес: Большая Филёвская Ул., д. 22, 121309, Москва
# Рейтинг: 9.0
#
# Название: Kolomenskoje (Музей-заповедник «Коломенское»)
# Адрес: Москва
# Рейтинг: 9.2
#
# Название: Новопушкинский сквер
# Адрес: Тверская ул., Москва
# Рейтинг: 8.2
#
# Название: Lefortovo Park (Лефортовский парк)
# Адрес: Красноказарменная Ул., вл. 1 (Головинская наб.), 111250, Москва
# Рейтинг: 8.4
#
# Название: Парк имени Ю. М. Лужкова
# Адрес: Москва
# Рейтинг: 8.9
#
# Название: Аллея
# Адрес: Москва
# Рейтинг: 8.7
#
# Название: Сквер Мстислава Ростроповича
# Адрес: Елисеевский пер., 125009, Москва
# Рейтинг: 8.0
#
# Название: Воронцовский парк
# Адрес: Академика Пилюгина Ул., д. 1, 117393, Москва
# Рейтинг: 8.9
#
# Название: Парк 50-летия Октября
# Адрес: Удальцова Ул., д. 22А (ул. Удальцова), 119454, Москва
# Рейтинг: 8.8
#
# Название: Молодёжная улица
# Адрес: Москва
# Рейтинг: 8.5
#
# Название: Парк Олимпийской деревни
# Адрес: Мичуринский просп., 119602, Москва
# Рейтинг: 9.1
#
# Название: Berezovaya Roshcha Park (Парк «Берёзовая роща»)
# Адрес: Куусинена, 8А (пр. Берёзовой рощи), 125252, Москва
# Рейтинг: 8.5
#
# Название: Крылатские холмы
# Адрес: Крылатская ул., Москва
# Рейтинг: 9.1
#
# Название: Покровское-Стрешнево
# Адрес: Москва
# Рейтинг: 9.0
#
# Название: Кусковский лесопарк
# Адрес: Москва
# Рейтинг: 8.9
#
# Название: Долина реки Сетунь
# Адрес: Москва
# Рейтинг: 8.7
#
# Название: Парк усадьбы Свиблово
# Адрес: Лазоревый Пр., 19 (ул. Просвещения), 129323, Москва
# Рейтинг: 8.9
#
# Название: Аллея Космонавтов
# Адрес: просп. Мира, Москва
# Рейтинг: 8.5
#
# Название: Kuskovo (Музей-усадьба «Кусково»)
# Адрес: Юности Ул., д. 2, 111402, Москва
# Рейтинг: 8.9
#
# Название: Сквер у Донского монастыря
# Адрес: Донская ул., 115419, Москва
# Рейтинг: 8.1
#
# Название: Kuzminki Park (Природно-исторический парк «Кузьминки-Люблино»)
# Адрес: Кузьминская Ул., д. 10, 109439, Москва
# Рейтинг: 8.8
#
# Название: Суворовский парк
# Адрес: Москва
# Рейтинг: 8.7
#
# Название: Tsaritsyno Park (Музей-заповедник «Царицыно»)
# Адрес: Дольская Ул., д. 1., Moscow, Russia, 115569, Москва
# Рейтинг: 9.2
#
# Название: Яблоневый сад
# Адрес: Москва
# Рейтинг: 8.9
#
# Название: Терлецкий лесопарк
# Адрес: Москва
# Рейтинг: 8.7
#
# Название: Останкинский сквер
# Адрес: Новомосковская ул., Москва
# Рейтинг: 8.3
#
# Название: Борисовские пруды
# Адрес: Каширское ш., Москва
# Рейтинг: 9.0
#
# Название: Meshersky Park (Мещерский парк)
# Адрес: 119619, Москва
# Рейтинг: 9.4
#
# Название: Мемориальный парк
# Адрес: Новопесчаная Ул., вл. 12, 125252, Москва
# Рейтинг: 8.3
#
# Название: Сноупарк
# Адрес: Москва
# Рейтинг: 8.6
